# %%
import imp, os
import pandas as pd
import numpy as np
#load the modules from the right dir...
imp.load_source('app', 'app.py')
from app import *

# %%
db_conn = DbCon()
df = db_conn.get_accounts()
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Username</th>
#       <th>pDonaterRank</th>
#       <th>Score</th>
#       <th>Kills</th>
#       <th>Deaths</th>
#       <th>pCoprank</th>
#       <th>pArrests</th>
#       <th>pTakedowns</th>
#       <th>pArrest_Assists</th>
#       <th>pTimes_Arrested</th>
#       <th>pSWAT_Rank</th>
#       <th>pJail_Escapes</th>
#       <th>kd_ratio</th>
#     </tr>
#     <tr>
#       <th>Account_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...
